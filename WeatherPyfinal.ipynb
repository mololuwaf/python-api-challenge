# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 590

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Get the JSON response from the OpenWeather API
    #response_json = requests.get(city_url).json()
    

    # Run an API request for each of the cities
    try: 

        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
    
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
      
        city_lng = city_weather['coord']['lon']
        city_max_temp = ((city_weather['main']['temp_max'] - 273.15)*(9/5))+32
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | hamilton
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | constitucion
# Processing Record 8 of Set 1 | sioux lookout
# Processing Record 9 of Set 1 | vallenar
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | tucurui
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | wanning
# Processing Record 15 of Set 1 | yulara
# Processing Record 16 of Set 1 | monte cristi
# City not found. Skipping...
# Processing Record 17 of Set 1 | katangli
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | maromitsa
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | zharkent
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | severo-kurilsk
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | lagoa
# Processing Record 31 of Set 1 | mugumu
# Processing Record 32 of Set 1 | tawzar
# City not found. Skipping...
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | te anau
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | khuzdar
# Processing Record 39 of Set 1 | bjerkvik
# Processing Record 40 of Set 1 | nim ka thana
# City not found. Skipping...
# Processing Record 41 of Set 1 | mastic beach
# Processing Record 42 of Set 1 | beyla
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | ketchikan
# Processing Record 45 of Set 1 | ginir
# Processing Record 46 of Set 1 | norman wells
# Processing Record 47 of Set 1 | marzuq
# Processing Record 48 of Set 1 | moorhead
# Processing Record 49 of Set 1 | hambantota
# Processing Record 50 of Set 1 | ixtapa
# Processing Record 0 of Set 2 | adrar
# Processing Record 1 of Set 2 | kavieng
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | quatre cocos
# Processing Record 4 of Set 2 | saldanha
# Processing Record 5 of Set 2 | mogadishu
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | kenai
# Processing Record 8 of Set 2 | karasjok
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | codrington
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | turukhansk
# Processing Record 15 of Set 2 | zhezkazgan
# Processing Record 16 of Set 2 | genc
# Processing Record 17 of Set 2 | amuntai
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | vanderhoof
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | terney
# Processing Record 22 of Set 2 | puerto leguizamo
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | san quintin
# Processing Record 25 of Set 2 | ushuaia
# Processing Record 26 of Set 2 | okhotsk
# Processing Record 27 of Set 2 | nikolskoye
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | snezhnogorsk
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | tuatapere
# Processing Record 35 of Set 2 | manicore
# Processing Record 36 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 2 | bambous virieux
# Processing Record 38 of Set 2 | port hardy
# Processing Record 39 of Set 2 | clyde river
# Processing Record 40 of Set 2 | matara
# Processing Record 41 of Set 2 | kytlym
# City not found. Skipping...
# Processing Record 42 of Set 2 | taywarah
# Processing Record 43 of Set 2 | qrendi
# Processing Record 44 of Set 2 | alindao
# Processing Record 45 of Set 2 | katherine
# Processing Record 46 of Set 2 | sola
# Processing Record 47 of Set 2 | longyearbyen
# Processing Record 48 of Set 2 | guerrero negro
# Processing Record 49 of Set 2 | provideniya
# Processing Record 0 of Set 3 | derzhavinsk
# Processing Record 1 of Set 3 | korla
# Processing Record 2 of Set 3 | fairbanks
# Processing Record 3 of Set 3 | shimoda
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | waipawa
# Processing Record 6 of Set 3 | shilka
# Processing Record 7 of Set 3 | kutum
# Processing Record 8 of Set 3 | alofi
# Processing Record 9 of Set 3 | vao
# Processing Record 10 of Set 3 | salalah
# Processing Record 11 of Set 3 | dunedin
# Processing Record 12 of Set 3 | mariental
# Processing Record 13 of Set 3 | san ignacio
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 3 | kattivakkam
# Processing Record 17 of Set 3 | chandler
# Processing Record 18 of Set 3 | sao joao da barra
# Processing Record 19 of Set 3 | labuan
# Processing Record 20 of Set 3 | sherghati
# Processing Record 21 of Set 3 | fort nelson
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | karasuk
# Processing Record 24 of Set 3 | tiksi
# Processing Record 25 of Set 3 | abbeville
# Processing Record 26 of Set 3 | hibbing
# Processing Record 27 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 28 of Set 3 | shellbrook
# Processing Record 29 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 3 | urmary
# Processing Record 31 of Set 3 | biak
# Processing Record 32 of Set 3 | omboue
# Processing Record 33 of Set 3 | port alfred
# Processing Record 34 of Set 3 | paragominas
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | morgan city
# Processing Record 37 of Set 3 | roebourne
# Processing Record 38 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 3 | geraldton
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | olafsvik
# Processing Record 42 of Set 3 | tuktoyaktuk
# Processing Record 43 of Set 3 | nouadhibou
# Processing Record 44 of Set 3 | castro
# Processing Record 45 of Set 3 | gwadar
# Processing Record 46 of Set 3 | camocim
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | hobyo
# Processing Record 49 of Set 3 | verkh-suetka
# Processing Record 0 of Set 4 | taybad
# Processing Record 1 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 4 | cayenne
# Processing Record 3 of Set 4 | ahipara
# Processing Record 4 of Set 4 | nome
# Processing Record 5 of Set 4 | bluff
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 4 | kysyl-syr
# Processing Record 9 of Set 4 | georgiyevka
# Processing Record 10 of Set 4 | balikpapan
# Processing Record 11 of Set 4 | olinda
# Processing Record 12 of Set 4 | namatanai
# Processing Record 13 of Set 4 | dunkirk
# Processing Record 14 of Set 4 | north bend
# Processing Record 15 of Set 4 | saskylakh
# Processing Record 16 of Set 4 | aleksandrovskoye
# Processing Record 17 of Set 4 | rajsamand
# Processing Record 18 of Set 4 | meulaboh
# Processing Record 19 of Set 4 | cidreira
# Processing Record 20 of Set 4 | butaritari
# Processing Record 21 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 4 | hasaki
# Processing Record 23 of Set 4 | divnomorskoye
# Processing Record 24 of Set 4 | caiaponia
# Processing Record 25 of Set 4 | macia
# Processing Record 26 of Set 4 | wichita falls
# Processing Record 27 of Set 4 | east london
# Processing Record 28 of Set 4 | puerto cabello
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | olavarria
# Processing Record 31 of Set 4 | arlit
# Processing Record 32 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 4 | sao filipe
# Processing Record 34 of Set 4 | bad essen
# Processing Record 35 of Set 4 | shiraoi
# Processing Record 36 of Set 4 | mar del plata
# Processing Record 37 of Set 4 | shelburne
# Processing Record 38 of Set 4 | carman
# Processing Record 39 of Set 4 | nagato
# Processing Record 40 of Set 4 | sorland
# Processing Record 41 of Set 4 | ponta do sol
# Processing Record 42 of Set 4 | port blair
# Processing Record 43 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 44 of Set 4 | lompoc
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | iqaluit
# Processing Record 47 of Set 4 | borogontsy
# Processing Record 48 of Set 4 | kahului
# Processing Record 49 of Set 4 | carauari
# Processing Record 0 of Set 5 | klaksvik
# Processing Record 1 of Set 5 | dzaoudzi
# Processing Record 2 of Set 5 | jingdezhen
# Processing Record 3 of Set 5 | labuhan
# Processing Record 4 of Set 5 | gorontalo
# Processing Record 5 of Set 5 | formosa do rio preto
# Processing Record 6 of Set 5 | tyulyachi
# Processing Record 7 of Set 5 | yankton
# Processing Record 8 of Set 5 | kruisfontein
# Processing Record 9 of Set 5 | atar
# Processing Record 10 of Set 5 | aqtobe
# Processing Record 11 of Set 5 | mingaora
# Processing Record 12 of Set 5 | birjand
# Processing Record 13 of Set 5 | pangani
# Processing Record 14 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 5 | ancud
# Processing Record 16 of Set 5 | moba
# Processing Record 17 of Set 5 | asau
# Processing Record 18 of Set 5 | faanui
# Processing Record 19 of Set 5 | kailua
# Processing Record 20 of Set 5 | tynda
# Processing Record 21 of Set 5 | borovskoy
# Processing Record 22 of Set 5 | bandarbeyla
# Processing Record 23 of Set 5 | iskateley
# Processing Record 24 of Set 5 | creel
# Processing Record 25 of Set 5 | saint-augustin
# Processing Record 26 of Set 5 | grootfontein
# Processing Record 27 of Set 5 | liuhe
# Processing Record 28 of Set 5 | san jose
# Processing Record 29 of Set 5 | general roca
# Processing Record 30 of Set 5 | imeni poliny osipenko
# Processing Record 31 of Set 5 | charyshskoye
# Processing Record 32 of Set 5 | oktyabrskoye
# Processing Record 33 of Set 5 | tarija
# Processing Record 34 of Set 5 | chapais
# Processing Record 35 of Set 5 | dungarvan
# Processing Record 36 of Set 5 | mezen
# Processing Record 37 of Set 5 | san patricio
# Processing Record 38 of Set 5 | kodino
# Processing Record 39 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 5 | bathsheba
# Processing Record 41 of Set 5 | kuandian
# Processing Record 42 of Set 5 | buala
# Processing Record 43 of Set 5 | burica
# City not found. Skipping...
# Processing Record 44 of Set 5 | kabare
# Processing Record 45 of Set 5 | lara
# Processing Record 46 of Set 5 | tolaga bay
# Processing Record 47 of Set 5 | tautira
# Processing Record 48 of Set 5 | whitehorse
# Processing Record 49 of Set 5 | shamkhal
# Processing Record 0 of Set 6 | byron bay
# Processing Record 1 of Set 6 | pietersburg
# Processing Record 2 of Set 6 | barrow
# Processing Record 3 of Set 6 | morwell
# Processing Record 4 of Set 6 | moron
# Processing Record 5 of Set 6 | floriano
# Processing Record 6 of Set 6 | araouane
# Processing Record 7 of Set 6 | broome
# Processing Record 8 of Set 6 | eslov
# Processing Record 9 of Set 6 | bethel
# Processing Record 10 of Set 6 | gunjur
# Processing Record 11 of Set 6 | belmonte
# Processing Record 12 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 6 | stuttgart
# Processing Record 16 of Set 6 | sieradz
# Processing Record 17 of Set 6 | malanje
# Processing Record 18 of Set 6 | loveland
# Processing Record 19 of Set 6 | vydrino
# Processing Record 20 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 21 of Set 6 | zeya
# Processing Record 22 of Set 6 | fairview
# Processing Record 23 of Set 6 | firminopolis
# Processing Record 24 of Set 6 | haines junction
# Processing Record 25 of Set 6 | egvekinot
# Processing Record 26 of Set 6 | smithers
# Processing Record 27 of Set 6 | igrim
# Processing Record 28 of Set 6 | khorixas
# Processing Record 29 of Set 6 | praia da vitoria
# Processing Record 30 of Set 6 | la ronge
# Processing Record 31 of Set 6 | husavik
# Processing Record 32 of Set 6 | royan
# Processing Record 33 of Set 6 | kavaratti
# Processing Record 34 of Set 6 | abha
# Processing Record 35 of Set 6 | longview
# Processing Record 36 of Set 6 | marawi
# Processing Record 37 of Set 6 | alyangula
# Processing Record 38 of Set 6 | vila velha
# Processing Record 39 of Set 6 | todireni
# Processing Record 40 of Set 6 | zemio
# Processing Record 41 of Set 6 | kununurra
# Processing Record 42 of Set 6 | sao luiz gonzaga
# Processing Record 43 of Set 6 | ostrovnoy
# Processing Record 44 of Set 6 | sabla
# Processing Record 45 of Set 6 | mehamn
# Processing Record 46 of Set 6 | crib point
# Processing Record 47 of Set 6 | ledyard
# Processing Record 48 of Set 6 | matadi
# Processing Record 49 of Set 6 | kurilsk
# Processing Record 0 of Set 7 | ribeira grande
# Processing Record 1 of Set 7 | ulladulla
# Processing Record 2 of Set 7 | bajil
# Processing Record 3 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 7 | ornskoldsvik
# Processing Record 5 of Set 7 | buta
# Processing Record 6 of Set 7 | nanakuli
# Processing Record 7 of Set 7 | puerto del rosario
# Processing Record 8 of Set 7 | chuy
# Processing Record 9 of Set 7 | lorengau
# Processing Record 10 of Set 7 | karratha
# Processing Record 11 of Set 7 | acajutla
# Processing Record 12 of Set 7 | abalak
# Processing Record 13 of Set 7 | airai
# Processing Record 14 of Set 7 | nova olimpia
# Processing Record 15 of Set 7 | sibu
# Processing Record 16 of Set 7 | port moresby
# Processing Record 17 of Set 7 | khunzakh
# Processing Record 18 of Set 7 | ati
# Processing Record 19 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 7 | flagstaff
# Processing Record 21 of Set 7 | krasnoselkup
# Processing Record 22 of Set 7 | nabire
# Processing Record 23 of Set 7 | bagdarin
# Processing Record 24 of Set 7 | marau
# Processing Record 25 of Set 7 | piacabucu
# Processing Record 26 of Set 7 | ternate
# Processing Record 27 of Set 7 | akropong
# Processing Record 28 of Set 7 | sapa
# Processing Record 29 of Set 7 | christchurch
# Processing Record 30 of Set 7 | muravlenko
# Processing Record 31 of Set 7 | golfito
# Processing Record 32 of Set 7 | aporawan
# City not found. Skipping...
# Processing Record 33 of Set 7 | tromso
# Processing Record 34 of Set 7 | pisco
# Processing Record 35 of Set 7 | coahuayana
# Processing Record 36 of Set 7 | hithadhoo
# Processing Record 37 of Set 7 | yuzhou
# Processing Record 38 of Set 7 | vilyuysk
# Processing Record 39 of Set 7 | leningradskiy
# Processing Record 40 of Set 7 | bulgan
# Processing Record 41 of Set 7 | mayumba
# Processing Record 42 of Set 7 | bonfim
# Processing Record 43 of Set 7 | xuanhua
# Processing Record 44 of Set 7 | jackson
# Processing Record 45 of Set 7 | paamiut
# Processing Record 46 of Set 7 | pevek
# Processing Record 47 of Set 7 | hualmay
# Processing Record 48 of Set 7 | esperance
# Processing Record 49 of Set 7 | port macquarie
# Processing Record 0 of Set 8 | sant feliu de guixols
# Processing Record 1 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 8 | sinnamary
# Processing Record 3 of Set 8 | kochevo
# Processing Record 4 of Set 8 | kimbe
# Processing Record 5 of Set 8 | santa isabel
# Processing Record 6 of Set 8 | ossora
# Processing Record 7 of Set 8 | los llanos de aridane
# Processing Record 8 of Set 8 | namibe
# Processing Record 9 of Set 8 | portland
# Processing Record 10 of Set 8 | bilibino
# Processing Record 11 of Set 8 | bairnsdale
# Processing Record 12 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 13 of Set 8 | kampene
# Processing Record 14 of Set 8 | touros
# Processing Record 15 of Set 8 | warragul
# Processing Record 16 of Set 8 | tanout
# Processing Record 17 of Set 8 | lake jackson
# Processing Record 18 of Set 8 | kommunar
# Processing Record 19 of Set 8 | baruun-urt
# Processing Record 20 of Set 8 | awbari
# Processing Record 21 of Set 8 | capreol
# Processing Record 22 of Set 8 | alice springs
# Processing Record 23 of Set 8 | muhos
# Processing Record 24 of Set 8 | muros
# Processing Record 25 of Set 8 | lebu
# Processing Record 26 of Set 8 | avera
# Processing Record 27 of Set 8 | buraydah
# Processing Record 28 of Set 8 | santa fe
# Processing Record 29 of Set 8 | petrovsk-zabaykalskiy
# Processing Record 30 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 8 | lasa
# Processing Record 32 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 8 | tiruchchendur
# Processing Record 34 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 35 of Set 8 | chernyshevsk
# Processing Record 36 of Set 8 | loucovice
# Processing Record 37 of Set 8 | muli
# Processing Record 38 of Set 8 | san angelo
# Processing Record 39 of Set 8 | bend
# Processing Record 40 of Set 8 | nagyszenas
# Processing Record 41 of Set 8 | san policarpo
# Processing Record 42 of Set 8 | paciran
# Processing Record 43 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 8 | alghero
# Processing Record 45 of Set 8 | fort wellington
# Processing Record 46 of Set 8 | aklavik
# Processing Record 47 of Set 8 | siniscola
# Processing Record 48 of Set 8 | morondava
# Processing Record 49 of Set 8 | birin
# Processing Record 0 of Set 9 | spornoye
# Processing Record 1 of Set 9 | laiwu
# Processing Record 2 of Set 9 | tura
# Processing Record 3 of Set 9 | spring valley
# Processing Record 4 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 9 | cabo san lucas
# Processing Record 6 of Set 9 | ilulissat
# Processing Record 7 of Set 9 | broken hill
# Processing Record 8 of Set 9 | roma
# Processing Record 9 of Set 9 | gravdal
# Processing Record 10 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 11 of Set 9 | arecibo
# Processing Record 12 of Set 9 | noyabrsk
# Processing Record 13 of Set 9 | saint-francois
# Processing Record 14 of Set 9 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 15 of Set 9 | micheweni
# Processing Record 16 of Set 9 | vostok
# Processing Record 17 of Set 9 | kedougou
# Processing Record 18 of Set 9 | caravelas
# Processing Record 19 of Set 9 | makakilo city
# Processing Record 20 of Set 9 | eureka
# Processing Record 21 of Set 9 | moose factory
# Processing Record 22 of Set 9 | mount gambier
# Processing Record 23 of Set 9 | saint-denis
# Processing Record 24 of Set 9 | gao
# Processing Record 25 of Set 9 | praya
# Processing Record 26 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 27 of Set 9 | charters towers
# Processing Record 28 of Set 9 | padang
# Processing Record 29 of Set 9 | banda aceh
# Processing Record 30 of Set 9 | kuusamo
# Processing Record 31 of Set 9 | fuerte olimpo
# Processing Record 32 of Set 9 | forbes
# Processing Record 33 of Set 9 | andarab
# City not found. Skipping...
# Processing Record 34 of Set 9 | pacific grove
# Processing Record 35 of Set 9 | honiara
# Processing Record 36 of Set 9 | berlevag
# Processing Record 37 of Set 9 | riyadh
# Processing Record 38 of Set 9 | taber
# Processing Record 39 of Set 9 | sisimiut
# Processing Record 40 of Set 9 | horta
# Processing Record 41 of Set 9 | kupang
# Processing Record 42 of Set 9 | banjar
# Processing Record 43 of Set 9 | krasnoarmeysk
# Processing Record 44 of Set 9 | beyneu
# Processing Record 45 of Set 9 | yar-sale
# Processing Record 46 of Set 9 | college
# Processing Record 47 of Set 9 | reefton
# City not found. Skipping...
# Processing Record 48 of Set 9 | gwanda
# Processing Record 49 of Set 9 | suntar
# Processing Record 0 of Set 10 | whithorn
# Processing Record 1 of Set 10 | hofn
# Processing Record 2 of Set 10 | cullman
# Processing Record 3 of Set 10 | comodoro rivadavia
# Processing Record 4 of Set 10 | itaguai
# Processing Record 5 of Set 10 | laem sing
# Processing Record 6 of Set 10 | dakar
# Processing Record 7 of Set 10 | matamoros
# Processing Record 8 of Set 10 | jiuquan
# Processing Record 9 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 10 | tateyama
# Processing Record 11 of Set 10 | nombre de dios
# Processing Record 12 of Set 10 | inhambane
# Processing Record 13 of Set 10 | san pedro
# Processing Record 14 of Set 10 | boende
# Processing Record 15 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 10 | altagracia de orituco
# Processing Record 17 of Set 10 | mareeba
# Processing Record 18 of Set 10 | ust-ilimsk
# Processing Record 19 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 10 | ipameri
# Processing Record 21 of Set 10 | qaqortoq
# Processing Record 22 of Set 10 | katsuura
# Processing Record 23 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 10 | daru
# Processing Record 25 of Set 10 | kharhial
# Processing Record 26 of Set 10 | bundaberg
# Processing Record 27 of Set 10 | bullhead city
# Processing Record 28 of Set 10 | golden
# Processing Record 29 of Set 10 | luderitz
# Processing Record 30 of Set 10 | tougue
# Processing Record 31 of Set 10 | narsaq
# Processing Record 32 of Set 10 | san cristobal
# Processing Record 33 of Set 10 | port lincoln
# Processing Record 34 of Set 10 | malur
# Processing Record 35 of Set 10 | gat
# Processing Record 36 of Set 10 | les escoumins
# Processing Record 37 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 38 of Set 10 | sirsi
# Processing Record 39 of Set 10 | carutapera
# Processing Record 40 of Set 10 | belaya gora
# Processing Record 41 of Set 10 | port hueneme
# Processing Record 42 of Set 10 | deputatskiy
# Processing Record 43 of Set 10 | vanimo
# Processing Record 44 of Set 10 | kon tum
# Processing Record 45 of Set 10 | changping
# Processing Record 46 of Set 10 | luanda
# Processing Record 47 of Set 10 | puente alto
# Processing Record 48 of Set 10 | shitanjing
# Processing Record 49 of Set 10 | nantucket
# Processing Record 0 of Set 11 | arman
# Processing Record 1 of Set 11 | catuday
# Processing Record 2 of Set 11 | viedma
# Processing Record 3 of Set 11 | alugan
# Processing Record 4 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 11 | fare
# Processing Record 6 of Set 11 | nesna
# Processing Record 7 of Set 11 | champerico
# Processing Record 8 of Set 11 | maniitsoq
# Processing Record 9 of Set 11 | lalmohan
# Processing Record 10 of Set 11 | balabac
# Processing Record 11 of Set 11 | beringovskiy
# Processing Record 12 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 14 of Set 11 | ayan
# Processing Record 15 of Set 11 | wawa
# Processing Record 16 of Set 11 | barcelos
# Processing Record 17 of Set 11 | walvis bay
# Processing Record 18 of Set 11 | surt
# Processing Record 19 of Set 11 | severo-yeniseyskiy
# Processing Record 20 of Set 11 | dingle
# Processing Record 21 of Set 11 | longonjo
# Processing Record 22 of Set 11 | ilhabela
# Processing Record 23 of Set 11 | hami
# Processing Record 24 of Set 11 | portlethen
# Processing Record 25 of Set 11 | sambava
# Processing Record 26 of Set 11 | maraa
# Processing Record 27 of Set 11 | akyab
# Processing Record 28 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 11 | jijiga
# Processing Record 30 of Set 11 | nhulunbuy
# Processing Record 31 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 32 of Set 11 | sumkino
# Processing Record 33 of Set 11 | capao da canoa
# Processing Record 34 of Set 11 | taloqan
# Processing Record 35 of Set 11 | palmer
# Processing Record 36 of Set 11 | kisangani
# Processing Record 37 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 38 of Set 11 | yerbogachen
# Processing Record 39 of Set 11 | mayo
# Processing Record 40 of Set 11 | semnan
# Processing Record 41 of Set 11 | lodja
# Processing Record 42 of Set 11 | tukrah
# Processing Record 43 of Set 11 | pangoa
# Processing Record 44 of Set 11 | saint-ambroise
# Processing Record 45 of Set 11 | bad salzuflen
# Processing Record 46 of Set 11 | doha
# Processing Record 47 of Set 11 | petrivka
# Processing Record 48 of Set 11 | srednekolymsk
# Processing Record 49 of Set 11 | mapimi
# Processing Record 0 of Set 12 | sao joao evangelista
# Processing Record 1 of Set 12 | kieta
# Processing Record 2 of Set 12 | camacha
# Processing Record 3 of Set 12 | kazanskoye
# Processing Record 4 of Set 12 | cotonou
# Processing Record 5 of Set 12 | poum
# Processing Record 6 of Set 12 | bilma
# Processing Record 7 of Set 12 | ribas do rio pardo
# Processing Record 8 of Set 12 | canitas
# City not found. Skipping...
# Processing Record 9 of Set 12 | muriti
# Processing Record 10 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 12 | abrau-dyurso
# Processing Record 12 of Set 12 | nandigama
# Processing Record 13 of Set 12 | bokoro
# Processing Record 14 of Set 12 | yamada
# Processing Record 15 of Set 12 | conde
# Processing Record 16 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 12 | rapid valley
# Processing Record 18 of Set 12 | shangzhi
# Processing Record 19 of Set 12 | murmashi
# Processing Record 20 of Set 12 | martapura
# Processing Record 21 of Set 12 | griffith
# Processing Record 22 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 12 | visby
# Processing Record 24 of Set 12 | koutsouras
# Processing Record 25 of Set 12 | zonguldak
# Processing Record 26 of Set 12 | maneadero
# Processing Record 27 of Set 12 | pastavy
# Processing Record 28 of Set 12 | marquard
# Processing Record 29 of Set 12 | sampit
# Processing Record 30 of Set 12 | kama
# Processing Record 31 of Set 12 | salihorsk
# Processing Record 32 of Set 12 | baghdad
# Processing Record 33 of Set 12 | kloulklubed
# Processing Record 34 of Set 12 | rostovka
# Processing Record 35 of Set 12 | yaguachi
# Processing Record 36 of Set 12 | jaisalmer
# Processing Record 37 of Set 12 | dori
# Processing Record 38 of Set 12 | udachnyy
# Processing Record 39 of Set 12 | minna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df.rename_axis('City ID')

# Show Record Count
city_data_df.count()
# Out:
# City          536
# Lat           536
# Lng           536
# Max Temp      536
# Humidity      536
# Cloudiness    536
# Wind Speed    536
# Country       536
# Date          536
# dtype: int64

# %%
# Display sample data
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City ID
# 0           kodiak  57.7900 -152.4072  -396.472       100         100
# 1        mahebourg -20.4081   57.7000  -314.068        69          40
# 2         hamilton  39.1834  -84.5333  -373.918        72         100
# 3          mataura -46.1927  168.8643  -361.606        70          18
# 4          rikitea -23.1203 -134.9692  -316.372        73           4
# ...            ...      ...       ...       ...       ...         ...
# 531       yaguachi  -2.1167  -79.6833  -301.342        60          91
# 532      jaisalmer  26.9147   70.9181  -335.290        29           2
# 533           dori  14.0354   -0.0345  -309.928         7           0
# 534       udachnyy  66.4167  112.4000  -519.196       100          91
# 535          minna   9.6139    6.5569  -302.152        29           0
#
#          Wind Speed Country        Date
# City ID
# 0              0.00      US  1676058204
# 1              9.22      MU  1676058205
# 2             11.50      US  1676058158
# 3              2.10      NZ  1676058205
# 4             19.33      PF  1676058206
# ...             ...     ...         ...
# 531            1.45      EC  1676058479
# 532            7.63      IN  1676058480
# 533            9.73      BF  1676058480
# 534            4.94      RU  1676058481
# 535            5.75      NG  1676058481
#
# [536 rows x 9 columns]

# %%
# Export the City_Data into a csv
city_data_df.to_csv("./output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("./output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           kodiak  57.7900 -152.4072  -396.472       100         100
# 1        mahebourg -20.4081   57.7000  -314.068        69          40
# 2         hamilton  39.1834  -84.5333  -373.918        72         100
# 3          mataura -46.1927  168.8643  -361.606        70          18
# 4          rikitea -23.1203 -134.9692  -316.372        73           4
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      US  1676058204
# 1              9.22      MU  1676058205
# 2             11.50      US  1676058158
# 3              2.10      NZ  1676058205
# 4             19.33      PF  1676058206

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# Incorporate the other graph properties
x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]

plt.scatter(x_values,y_values)
plt.title('Latitude v Temp')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
# plt.ylim(0, 100)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.savefig("./output_data/latvtemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties
x_values = city_data_df["Lat"]
y_values = city_data_df["Humidity"]

plt.scatter(x_values,y_values)
plt.title('Latitude v Humidity')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(0, 100)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.savefig("./output_data/latvhum.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# Incorporate the other graph properties
x_values = city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]

plt.scatter(x_values,y_values)
plt.title('Latitude v Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.savefig("./output_data/latvcloud.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# Incorporate the other graph properties
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]

plt.scatter(x_values,y_values)
plt.title('Latitude v Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.savefig("./output_data/latvwindspeed.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_reg_plot(x_values, y_values, title,text_coordinates):

    # compute linear regression
    (slope, intercept, rvalue, pvalue, stderr, intercept_stderr) = linregress(x_values, y_values)
    # set regression values
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=14,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0,:]
# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               kodiak  57.7900 -152.4072  -396.472       100         100
# 2             hamilton  39.1834  -84.5333  -373.918        72         100
# 6        sioux lookout  50.1001  -91.9170  -434.344        57          75
# 8                 hilo  19.7297 -155.0900  -326.578        87          75
# 11        saint george  37.1041 -113.5841  -364.360        24           0
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      US  1676058204
# 2             11.50      US  1676058158
# 6              9.22      CA  1676058207
# 8              4.00      US  1676058187
# 11             4.61      US  1676058209

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           mahebourg -20.4081   57.7000  -314.068        69          40
# 3             mataura -46.1927  168.8643  -361.606        70          18
# 4             rikitea -23.1203 -134.9692  -316.372        73           4
# 5        constitucion -35.3333  -72.4167  -331.312        58          19
# 7            vallenar -28.5708  -70.7581  -299.938        28           2
#
#          Wind Speed Country        Date
# City_ID
# 1              9.22      MU  1676058205
# 3              2.10      NZ  1676058205
# 4             19.33      PF  1676058206
# 5             21.03      CL  1676058206
# 7              9.26      CL  1676058207

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Max Temperature v Latitude (linear Reg - Northern Hemisphere)')
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Max Temperature v Latitude (linear Reg - Northern Hemisphere)')
# Out:
# Text(0.5, 1.0, 'Max Temperature v Latitude (linear Reg - Northern Hemisphere)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Humidity v Latitude (linear Reg - Northern Hemisphere)')
plt.show()

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Humidity v Latitude (linear Reg - Southern Hemisphere)')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness v Latitude (linear Reg - Northern Hemisphere)')
plt.show()

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness v Latitude (linear Reg - Southern Hemisphere)')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness v Latitude (linear Reg - Northern Hemisphere)')
plt.show()

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness v Latitude (linear Reg - Southern Hemisphere)')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
